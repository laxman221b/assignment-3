# %%
import pandas as pd
import numpy as np
import seaborn as sbn
import matplotlib.pyplot as plt

# %%
# reading dataset

df=pd.read_excel('ameo2015.xlsx')
print(df)
# Out:
#      Unnamed: 0       ID   Salary        DOJ                  DOL  \
# 0         train   203097   420000 2012-06-01              present
# 1         train   579905   500000 2013-09-01              present
# 2         train   810601   325000 2014-06-01              present
# 3         train   267447  1100000 2011-07-01              present
# 4         train   343523   200000 2014-03-01  2015-03-01 00:00:00
# 5         train  1027655   300000 2014-06-01              present
# 6         train   947847   300000 2014-08-01  2015-05-01 00:00:00
# 7         train   912934   400000 2014-07-01  2015-07-01 00:00:00
# 8         train   552574   600000 2013-07-01              present
# 9         train  1203363   230000 2014-07-01              present
# 10        train    87291   600000 2011-04-01  2015-04-01 00:00:00
# 11        train   190393   450000 2011-08-01  2014-10-01 00:00:00
# 12        train   606655   270000 2013-12-01              present
# ...

# %%
# number of data points

print(df.shape)

#names of columns

print(df.columns)

#statistical and numerical data about dataset

df.describe()
# Out:
# (3998, 39)
# Index(['Unnamed: 0', 'ID', 'Salary', 'DOJ', 'DOL', 'Designation', 'JobCity',
#        'Gender', 'DOB', '10percentage', '10board', '12graduation',
#        '12percentage', '12board', 'CollegeID', 'CollegeTier', 'Degree',
#        'Specialization', 'collegeGPA', 'CollegeCityID', 'CollegeCityTier',
#        'CollegeState', 'GraduationYear', 'English', 'Logical', 'Quant',
#        'Domain', 'ComputerProgramming', 'ElectronicsAndSemicon',
#        'ComputerScience', 'MechanicalEngg', 'ElectricalEngg', 'TelecomEngg',
#        'CivilEngg', 'conscientiousness', 'agreeableness', 'extraversion',
#        'nueroticism', 'openess_to_experience'],
#       dtype='object')
#                  ID        Salary  10percentage  12graduation  12percentage  \
# count  3.998000e+03  3.998000e+03   3998.000000   3998.000000   3998.000000
# mean   6.637945e+05  3.076998e+05     77.925443   2008.087544     74.466366
# std    3.632182e+05  2.127375e+05      9.850162      1.653599     10.999933
# ...

# %%
# finding outliers in numerical columns 

#outliers in salary
plt.boxplot(df['Salary'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23c8b55d400>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x23c8b55da90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x23c8b54efd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x23c8b55deb8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x23c8b5684a8>],
#  'means': []}

# %%
#outliers in 10th %
plt.boxplot(df['10percentage'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23c8b626780>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x23c8b626e80>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x23c8b626390>],
#  'medians': [<matplotlib.lines.Line2D at 0x23c8b631550>],
#  'fliers': [<matplotlib.lines.Line2D at 0x23c8b631898>],
#  'means': []}

# %%
#outliers in 12th %
plt.boxplot(df['12percentage'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23c8b6e0f98>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x23c8b6ed978>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x23c8b6e0e48>],
#  'medians': [<matplotlib.lines.Line2D at 0x23c8b6edda0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x23c8b6fa390>],
#  'means': []}

# %%
#outliers in college GPA
plt.boxplot(df['collegeGPA'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23c8b7ad748>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x23c8b7ade48>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x23c8b7ad358>],
#  'medians': [<matplotlib.lines.Line2D at 0x23c8b7bb518>],
#  'fliers': [<matplotlib.lines.Line2D at 0x23c8b7bb860>],
#  'means': []}

# %%
#outliers in english score

plt.boxplot(df['English'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23c8ae57fd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x23c8aead710>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x23c8ae57be0>],
#  'medians': [<matplotlib.lines.Line2D at 0x23c8aeadda0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x23c8aeade80>],
#  'means': []}

# %%
#outliers in logical scores 

plt.boxplot(df['Logical'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23c8b918550>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x23c8b918c50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x23c8b918160>],
#  'medians': [<matplotlib.lines.Line2D at 0x23c8b918f28>],
#  'fliers': [<matplotlib.lines.Line2D at 0x23c8b923668>],
#  'means': []}

# %%
#outliers in quant scores

plt.boxplot(df['Quant'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23c8b9d9f98>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x23c8b9e76d8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x23c8b9d9ba8>],
#  'medians': [<matplotlib.lines.Line2D at 0x23c8b9e7d68>],
#  'fliers': [<matplotlib.lines.Line2D at 0x23c8b9e7e48>],
#  'means': []}

# %%
#outliers in domain

plt.boxplot(df['Domain'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23c8ca8d390>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x23c8ca8da90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x23c8ca7df60>],
#  'medians': [<matplotlib.lines.Line2D at 0x23c8ca8deb8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x23c8ca41748>],
#  'means': []}

# %%
# outliers in computer column

plt.boxplot(df['ComputerProgramming'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23c8cb662e8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x23c8cb669e8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x23c8cb5aeb8>],
#  'medians': [<matplotlib.lines.Line2D at 0x23c8cb66e10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x23c8cb71400>],
#  'means': []}

# %%
#outliers in electronics 

plt.boxplot(df['ElectronicsAndSemicon'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23c8cc1c780>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x23c8cc1ce80>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x23c8cc1c390>],
#  'medians': [<matplotlib.lines.Line2D at 0x23c8cc29550>],
#  'fliers': [<matplotlib.lines.Line2D at 0x23c8cc29898>],
#  'means': []}

# %%
#outliers in ComputerScience
plt.boxplot(df['ComputerScience'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23c8ccdfb70>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x23c8ccdfeb8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x23c8ccdf780>],
#  'medians': [<matplotlib.lines.Line2D at 0x23c8cced940>],
#  'fliers': [<matplotlib.lines.Line2D at 0x23c8ccedc88>],
#  'means': []}

# %%
#outliers in MechanicalEngg
plt.boxplot(df['MechanicalEngg'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23c8cdb8e48>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x23c8cdc5828>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x23c8cdb8cf8>],
#  'medians': [<matplotlib.lines.Line2D at 0x23c8cdc5eb8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x23c8cdc5f98>],
#  'means': []}

# %%
#outliers in ElectricalEngg
plt.boxplot(df['ElectricalEngg'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23c8ce87550>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x23c8ce87c50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x23c8ce87160>],
#  'medians': [<matplotlib.lines.Line2D at 0x23c8ce87f28>],
#  'fliers': [<matplotlib.lines.Line2D at 0x23c8ce90668>],
#  'means': []}

# %%
#outkiers in TelecomEngg
plt.boxplot(df['TelecomEngg'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23c8cf4c438>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x23c8cf4cb38>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x23c8cf4c048>],
#  'medians': [<matplotlib.lines.Line2D at 0x23c8cf4cf60>],
#  'fliers': [<matplotlib.lines.Line2D at 0x23c8cf56550>],
#  'means': []}

# %%
#outliers in CivilEngg
plt.boxplot(df['CivilEngg'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23c8d00b860>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x23c8d00bf60>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x23c8d00b470>],
#  'medians': [<matplotlib.lines.Line2D at 0x23c8d017630>],
#  'fliers': [<matplotlib.lines.Line2D at 0x23c8d017978>],
#  'means': []}

# %%
#outliers in conscientiousness
plt.boxplot(df['conscientiousness'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23c8d0cdef0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x23c8d0d9860>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x23c8d0cdda0>],
#  'medians': [<matplotlib.lines.Line2D at 0x23c8d0d9ef0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x23c8d0d9fd0>],
#  'means': []}

# %%
#outliers in agreeableness
plt.boxplot(df['agreeableness'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23c8d1a8630>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x23c8d1a8d30>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x23c8d1a8240>],
#  'medians': [<matplotlib.lines.Line2D at 0x23c8d1b0400>],
#  'fliers': [<matplotlib.lines.Line2D at 0x23c8d1b0748>],
#  'means': []}

# %%
#outliers in extraversion
plt.boxplot(df['extraversion'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23c8d26ec18>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x23c8d26ef60>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x23c8d26e828>],
#  'medians': [<matplotlib.lines.Line2D at 0x23c8d27c9e8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x23c8d27cd30>],
#  'means': []}

# %%
#outliers in nueroticism
plt.boxplot(df['nueroticism'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23c8d33d358>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x23c8d33da58>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x23c8d331f28>],
#  'medians': [<matplotlib.lines.Line2D at 0x23c8d33de80>],
#  'fliers': [<matplotlib.lines.Line2D at 0x23c8d348470>],
#  'means': []}

# %%
#outliers in openess_to_experience
plt.boxplot(df['openess_to_experience'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23c8d3f3f98>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x23c8d4026d8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x23c8d3f3ba8>],
#  'medians': [<matplotlib.lines.Line2D at 0x23c8d402d68>],
#  'fliers': [<matplotlib.lines.Line2D at 0x23c8d402e48>],
#  'means': []}

# %%
# probabilty an freq. distribution plot for all numerical columns 

sbn.distplot(df['Salary'])

# %%
#for 10th  %

sbn.distplot(df['10percentage'])

# %%
# for 12th percentage

sbn.distplot(df['12percentage'])

# %%
# for college GPA
sbn.distplot(df['collegeGPA'])

# %%
# for English column
sbn.distplot(df['English'])

# %%
# for logical column
sbn.distplot(df['Logical'])

# %%
#for Quant column
sbn.distplot(df['Quant'])

# %%
#for domain column
sbn.distplot(df['Domain'])

# %%
# for computer programming
sbn.distplot(df['ComputerProgramming'])

# %%
# for electronics and semicon

sbn.distplot(df['ElectronicsAndSemicon'])

# %%
#for computer science
sbn.distplot(df['ComputerScience'])

# %%
# for mechaical engineering
sbn.distplot(df['MechanicalEngg'])

# %%
# for electrical engineering
sbn.distplot(df['ElectricalEngg'])

# %%
#for Telecom engineering
sbn.distplot(df['TelecomEngg'])

# %%
#for civil enginering
sbn.distplot(df['CivilEngg'])

# %%
# frequency distribution plots for categrical data columns

# for gender column
sbn.countplot(df['Gender'])

#there are more males in this company than females

# %%
# for designation 

sbn.countplot(y='Designation',data=df)

# there are so many designations that it's very difficult to read graph

# %%
# for job city

sbn.countplot(y='JobCity',data=df)

#here also there are so many cities that understanding visual data is difficult

# %%
# for degree 

sbn.countplot(df['Degree'])

#there are more than 3500 employee graduated from B.tech/B.E degree

# %%
# for specialization

sbn.countplot(y='Specialization',data=df)

# too many categories so analyzing visual data is difficult 
#there are more than 800 employees specialized in electronics and comunication engineering

# %%
#for college city tier

sbn.countplot(df['CollegeCityTier'])

# %%
# for college state

sbn.countplot(y="CollegeState",data=df)

#there are more than 800 employee from college in uttar pradesh

# %%
#bivariate analysis

# %%
# pairplot for this dataset is very difficult to read as there is very large data

# %%
#'''so we have to plot scatter plot ,boxplot, swarmplot and barplot for every
#possible columns to find out the relation between the target variable which
#is salary and other variables.

# %%
#scatter plot b/w 10th percentage and salary

sbn.scatterplot(x="10percentage",y="Salary",data=df)

#according to this plot there is not much change in salary due to 10th percentage

# %%
#scatter plot b/w salary and 12th percentage

sbn.scatterplot(x="12percentage",y="Salary",data=df)

# here also there is no noticiable differnce in salary due to 12th percentage

# %%
# scatter plot for collegeGPA and salary

sbn.scatterplot(x="collegeGPA",y="Salary",data=df)

#according to plot the college GPA aren't much affecting Salary

# %%
#scatter plot b/w english scores and Salary 

sbn.scatterplot(x="English",y="Salary",data=df)

#here plot is not showing any changes in salary due to english scores.

# %%
#scatter plot b/w Logical and Salary

sbn.scatterplot(x="Logical",y="Salary",data=df)

#according to plot there is slight changes in salary due to Logical scores,

# %%
# scatter plot b/w Quant scores and Salary

sbn.scatterplot(x="Quant",y="Salary",data=df)

#again no changes in salary due to quant scores.

# %%
#scatter plot b/w domain and Salary

sbn.scatterplot(x="Domain",y="Salary",data=df)

#no changes in salary due to domain

# %%
#scatter plot b/w ComputerProgramming and Salary

sbn.scatterplot(x="ComputerProgramming",y="Salary",data=df)

#again no major realation b/w computer programming and salary

# %%
#scatter plot b/w ElectronicsAndSemicon and salary

sbn.scatterplot(x="ElectronicsAndSemicon",y="Salary",data=df)

#no relation b/w ElectronicsAndSemicon and Salary

# %%
# scatter plot b/w ComputerScience and Salary

sbn.scatterplot(x="ComputerScience",y="Salary",data=df)

#no major changes in salary due to ComputerScience

# %%
#scatter plot b/w MechanicalEngg and salary

sbn.scatterplot(x="MechanicalEngg",y="Salary",data=df)

#no major changes in salary due to MechanicalEngg

# %%
# scatter plot b/w ElectricalEngg and salary

sbn.scatterplot(x="ElectricalEngg",y="Salary",data=df)

#no change in salary due to ElectricalEngg

# %%
#scatterplot b/w TelecomEngg and Salary 

sbn.scatterplot(x="TelecomEngg",y="Salary",data=df)

#no major relation b/w TelecomEngg and Salary

# %%
#scatter plot b/w CivilEngg and Salary

sbn.scatterplot(x="CivilEngg",y="Salary",data=df)

#no major realtion b/w CivilEngg and Salary

# %%
# scatter plot b/w conscientiousness and Salary

sbn.scatterplot(x="conscientiousness",y="Salary",data=df)

# %%
#scatterplot b/w agreeableness and Salary

sbn.scatterplot(x="agreeableness",y="Salary",data=df)

#there are some noticiable increament in salary when agreeableness increases

# %%
# scatter plot b/w extraversion and salary

sbn.scatterplot(x="extraversion",y="Salary",data=df)

#slight increament in salary due to extraversion

# %%
# scatter plot b/w nueroticism and salary

sbn.scatterplot(x="nueroticism",y="Salary",data=df)

#no relation b/w nueroticism and salary

# %%
# scaatter plot b/w openess_to_experience and salary

sbn.scatterplot(x="openess_to_experience",y="Salary",data=df)

#salary and openess_to_experience are directly proportional

# %%
# now for categorical datas barplots and swarmplots

# %%
#barplot for Designation and Salary

fig_dim=(6,10)
fig,ax=plt.subplots(figsize=fig_dim)
sbn.barplot(x="Salary",y="Designation",data=df)

#it's quite obvious that Designation will definitely affect the salary
#and it's very difficult to read the barplot for this data as it is very large

# %%
#barplot for jobcity and salary

sbn.barplot(x="Salary",y="JobCity",data=df)

#job city is also affecting Salary but we can't say which city is this as there's too many cities

# %%
# barplot b/w gender and salary

sbn.barplot(x="Gender",y="Salary",data=df)

#there's no major difference in salary of males and female employees

# %%
#swarmplot for gender and Salary

sbn.swarmplot(x="Gender",y="Salary",data=df)

# %%
# barplot for CollegeTier and Salary

sbn.barplot(x="CollegeTier",y="Salary",data=df)

#from graph it is clear that employees from tier-1 college have higher salary than employees from 
# tier-2 college

# %%
#barplot for Degree and salary

sbn.barplot(x="Degree",y="Salary",data=df)

#the barplot below is clearly showing that students graduated from M.tech/M.E have higher salary than
#employees graduated from other degrees

# %%
#barplot for Specialization and Salary

fig_dim=(6,10)
fig,ax=plt.subplots(figsize=fig_dim)
sbn.barplot(x="Salary",y="Specialization",data=df)

#from graph it's clear that employees who have specializaion in polymer technology have higher salary.

# %%
# barplot for CollegeCityTier and salary 

sbn.barplot(x="CollegeCityTier",y="Salary",data=df)

#from graph we can see that there isn't much difference in the salary of employees from 0 or 1 tier city colleges but yes 
#there is very small differnce  salary for ( collegecity tier 1 > collegecity tier 0 )

# %%
# barplot for CollegeState and Salary

fig_dim=(8,10)
fig,ax=plt.subplots(figsize=fig_dim)
sbn.barplot(x="Salary",y="CollegeState",data=df)

#according to this graph the empoyees graduated from colleges in the meghalaya have higher salary.

# %%
#barplot for 10th board and salary

fig_dim=(10,40)
fig,ax=plt.subplots(figsize=fig_dim)
sbn.barplot(x="Salary",y="10board",data=df)

#on expanding the graph we see that employees whose 10th board was U.P. board have higher salary

# %%
# barplot for 12th board and Salary

fig_dim=(10,40)
fig,ax=plt.subplots(figsize=fig_dim)
sbn.barplot(x="Salary",y="12board",data=df)

#this graph also shows that employees from 12th U.P. board have higher salary.

# %%
#boxplot for gender and Salary

sbn.boxplot(x="Gender",y="Salary",data=df)

#its clear that males have much more outliers and also gender is not affecting Salary which is quite obvious.

# %%
#boxplot for CollegeTier and salary

sbn.boxplot(x="CollegeTier",y="Salary",data=df)

#from grapgh it's clear that employees from college tier 1 have higher salary than employees from college tier 2
#but there are many outliers in college tier 2 also who have higher salary.

# %%
#boxplot for Degree and Salary

sbn.boxplot(x="Degree",y="Salary",data=df)

#from graph it is cleear that employee with graduation in M.tech/M.E. have highe salary than other employees
#but there are also students from B.tech who also higher salary than M.tech act as outliers in data.

# %%
#boxplot for college city tier and salary

sbn.boxplot(x="CollegeCityTier",y="Salary",data=df)

#according to graph the employees from both tier 0 and tier 1 city colleges aren't affecting Salary
#but there are some outliers in city tier 0 employees having higher salary

# %%
#CONCLUSION

#By plotting different graphs between the salary and other columns here we can conclude that which column is actually 
#affecting the Salary.

# 1. Qualities like agreableness , openness to experience and extra version seems to be helping in increament of salary.

# 2. There are factors like Designation ,jobcity ,collegetier, Degree, specialization which are obvious factors that affects Salary.

# 3. Also there are other factors like Gender, college city tier,10th percentage, 12th percentage, 10th board, 12th board which doesn't affect the Salary 
#  but it seems due to some outliers as we know that if someone had performed well in 10th, 12th, and college years than the 
# person may be hardworking which makes them eligible for a good post in company and which is directly related to the Salary.

# 4. There are factors which were obvious and showed a good relation b/w them and Salary.Those factors are as follows :

# (i) Designation
# (ii) Specialization
# (iii) College tier
# (iv) Degree
# (v) Job city

# As per the discussion there are other qualities also which in some cases result into increament in salary.

# (i) Agreableness
# (ii) Extraversion
# (iii) Openness to experience
